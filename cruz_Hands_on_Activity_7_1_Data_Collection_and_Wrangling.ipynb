# %% [markdown]
# # Module 7: Data Wrangling with Pandas </br>
# ## CPE311 Computational Thinking with Python
#
# **Submitted by:** Cruz, Axl Waltz <br>
# **Performed on:** 02/24/2026 <br>
# **Submitted on:** 02/24/2026 <br>
# **Submitted to:** Engr. Neal Barton James Matira

# %% [markdown]
# ## 7.1 Supplementary Activity
# ### Exercise 1: Combining FAANG Data
# 1. Read each file (Facebook, Apple, Amazon, Netflix, and Google).
# 2. Add a `ticker` column to each (e.g., AAPL).
# 3. Append them into a single dataframe named `faang`.
# 4. Save the result as `faang.csv`.

# %%
import sys

# !{sys.executable} -m pip install pandas requests beautifulsoup4

# %%
import os

os.getcwd()
os.listdir()
# Out:
# ['.config',
#  'nflx.csv',
#  'fb.csv',
#  'goog.csv',
#  'aapl.csv',
#  'amzn.csv',
#  'sample_data']

# %%
import pandas as pd
import pandas as pd

tickers = ['fb', 'aapl', 'amzn', 'nflx', 'goog']

faang = pd.concat(
    [pd.read_csv(f'{t}.csv').assign(ticker=t.upper()) for t in tickers],
    ignore_index=True
)

faang.to_csv('faang.csv', index=False)
faang.head()
# Out:
#          date    open    high       low   close    volume ticker
# 0  2018-01-02  177.68  181.58  177.5500  181.42  18151903     FB
# 1  2018-01-03  181.88  184.78  181.3300  184.67  16886563     FB
# 2  2018-01-04  184.90  186.21  184.0996  184.33  13880896     FB
# 3  2018-01-05  185.59  186.90  184.9300  186.85  13574535     FB
# 4  2018-01-08  187.20  188.90  186.3300  188.28  17994726     FB

# %% [markdown]
# ### Exercise 2: Data Cleaning and Reshaping
# * Convert `date` to datetime and `volume` to integers.
# * Sort by `date` and `ticker`.
# * Find the seven rows with the highest `volume`.
# * Melt the dataframe into long format using `date` and `ticker` as ID variables.

# %%
# Type conversion
faang = faang.astype({'volume': 'int'})
faang['date'] = pd.to_datetime(faang['date'])

# Sorting
faang = faang.sort_values(['date', 'ticker'])

# Seven highest volume rows
top_7_volume = faang.nlargest(7, 'volume')

# Melt to long format
faang_long = faang.melt(
    id_vars=['date', 'ticker'],
    value_vars=['open', 'high', 'low', 'close', 'volume']
)

faang_long.head()
# Out:
#         date ticker variable      value
# 0 2018-01-02   AAPL     open   166.9271
# 1 2018-01-02   AMZN     open  1172.0000
# 2 2018-01-02     FB     open   177.6800
# 3 2018-01-02   GOOG     open  1048.3400
# 4 2018-01-02   NFLX     open   196.1000

# %% [markdown]
# ### Exercise 3: Web Scraping Hospitals
# * Scrape a list of hospitals (Name, Address, Contact Info).
# * Save to `hospitals.csv`.
# * Load into a dataframe and perform preprocessing.

# %%
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/List_of_hospitals_in_the_Philippines"
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})

tables = pd.read_html(response.text)

filtered_tables = [
    df.rename(columns={'Name of Hospital': 'Hospital Name', 'Location': 'Address'})
      .loc[lambda x: x['Class'].str.contains('LGU|DOH', case=False, na=False),
           ['Hospital Name', 'Address', 'Class']]
    for df in tables
    if {'Name of Hospital', 'Class'}.issubset(df.columns)
]

final_df = pd.concat(filtered_tables, ignore_index=True).head(100)

final_df.to_csv('hospitals.csv', index=False)

print(f"Total entries captured: {len(final_df)}")
display(final_df)
# Out:
# Total entries captured: 100
# /tmp/ipython-input-3144150264.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
#                                    Hospital Name  \
# 0                   Caloocan City Medical Center
# 1                             Ospital ng Malabon
# 2              San Lorenzo Ruiz General Hospital
# 3   Gat Andres Bonifacio Memorial Medical Center
# 4                               Ospital ng Tondo
# ..                                           ...
# 95           Region II Trauma and Medical Center
# 96                      Aurora Memorial Hospital
# 97          Jose C. Payumo Jr. Memorial Hospital
# 98                   Mariveles District Hospital
# 99                       Orani District Hospital
#
#                                               Address         Class
# ...

# %% [markdown]
# ## 7.2 Conclusion:
#
# This activity strengthened my understanding of data wrangling by using pandas, bs4, and requests to extract and clean data from multiple sources. Combining datasets with pd.concat() highlighted how structured integration is essential, especially for multi-entity time series data. Reshaping data with melt() reinforced the value of organizing variables properly for clearer analysis and visualization.
#
# The hospital scraping task also showed that real-world data is often unstructured and requires careful filtering and preprocessing. Overall, using Python to automate cleaning and validation makes the process more reliable and scalable than manual work.
