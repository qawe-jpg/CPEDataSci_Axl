# %% [markdown]
# Cruz, Axl Waltz E. <br>
# CPE311 - CPE22S3<br>
# 03/31/26<br>
# Engr.Neal Matira

# %%
import pandas as pd

df = pd.read_csv("asia_macro_economic_dataset.csv")
df.head()
# Out:
#        Country Country_Code  Year  Agriculture_value_added  \
# 0  Afghanistan          AFG  1975                      NaN
# 1  Afghanistan          AFG  1976                      NaN
# 2  Afghanistan          AFG  1977                      NaN
# 3  Afghanistan          AFG  1978                      NaN
# 4  Afghanistan          AFG  1979                      NaN
#
#    Current_account_balance  Exports_percent_GDP  External_debt  \
# 0                      NaN                  NaN            NaN
# 1                      NaN                  NaN            NaN
# 2                      NaN                  NaN            NaN
# 3                      NaN                  NaN            NaN
# 4                      NaN                  NaN            NaN
#
#    FDI_percent_GDP  GDP_USD  GDP_growth  ...  Imports_percent_GDP  \
# 0              NaN      NaN         NaN  ...                  NaN
# 1              NaN      NaN         NaN  ...                  NaN
# 2              NaN      NaN         NaN  ...                  NaN
# 3              NaN      NaN         NaN  ...                  NaN
# 4              NaN      NaN         NaN  ...                  NaN
#
#    Industry_value_added  Inflation  Life_expectancy  \
# 0                   NaN        NaN           39.994
# 1                   NaN        NaN           40.518
# 2                   NaN        NaN           41.082
# 3                   NaN        NaN           40.086
# 4                   NaN        NaN           38.844
#
#    Manufacturing_value_added  Population  Population_growth  \
# 0                        NaN  12773954.0           2.415250
# 1                        NaN  13059851.0           2.213446
# 2                        NaN  13340756.0           2.128100
# 3                        NaN  13611441.0           2.008698
# 4                        NaN  13655567.0           0.323659
#
#    Services_value_added  Trade_percent_GDP  Unemployment
# 0                   NaN                NaN           NaN
# 1                   NaN                NaN           NaN
# 2                   NaN                NaN           NaN
# 3                   NaN                NaN           NaN
# 4                   NaN                NaN           NaN
#
# [5 rows x 23 columns]

# %%
df.info()


df = df.dropna()


df['column_name'] = pd.to_numeric(df['column_name'], errors='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    2350 non-null   object
#  1   Country_Code               2350 non-null   object
#  2   Year                       2350 non-null   int64
#  3   Agriculture_value_added    1847 non-null   float64
#  4   Current_account_balance    1644 non-null   float64
#  5   Exports_percent_GDP        1841 non-null   float64
#  6   External_debt              1321 non-null   float64
#  7   FDI_percent_GDP            1979 non-null   float64
#  8   GDP_USD                    2086 non-null   float64
#  9   GDP_growth                 2089 non-null   float64
#  10  GDP_per_capita             2086 non-null   float64
#  11  Government_expenditure     1834 non-null   float64
#  12  Gross_capital_formation    1745 non-null   float64
#  13  Imports_percent_GDP        1841 non-null   float64
#  14  Industry_value_added       1822 non-null   float64
#  15  Inflation                  1758 non-null   float64
#  16  Life_expectancy            2303 non-null   float64
#  17  Manufacturing_value_added  1577 non-null   float64
#  18  Population                 2350 non-null   float64
#  19  Population_growth          2350 non-null   float64
#  20  Services_value_added       1735 non-null   float64
#  21  Trade_percent_GDP          1841 non-null   float64
#  22  Unemployment               1597 non-null   float64
# dtypes: float64(20), int64(1), object(2)
# memory usage: 422.4+ KB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2977/2671537911.py in <cell line: 0>()
#       5
#       6
# ----> 7 df['column_name'] = pd.to_numeric(df['column_name'], errors='coerce')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'column_name'

# %%
df.describe()
# Out:
#               Year  Agriculture_value_added  Current_account_balance  \
# count   640.000000               640.000000               640.000000
# mean   2009.403125                15.458128                -2.569036
# std       8.896905                 8.945833                15.311160
# min    1991.000000                 1.400166               -43.771235
# 25%    2002.000000                 8.575914                -6.531206
# 50%    2010.500000                13.534234                -2.156320
# 75%    2017.000000                21.384293                 1.118314
# max    2023.000000                47.724560               235.750597
#
#        Exports_percent_GDP  External_debt  FDI_percent_GDP       GDP_USD  \
# count           640.000000   6.400000e+02       640.000000  6.400000e+02
# mean             34.131952   1.069609e+11         3.735242  5.068039e+11
# std              18.252044   2.856390e+11         6.021721  1.973888e+12
# min               2.409013   7.603532e+07       -37.172653  7.684016e+08
# 25%              20.173376   6.008963e+09         0.695937  1.002169e+10
# 50%              31.346937   2.189262e+10         2.033641  5.143826e+10
# 75%              46.504205   9.384825e+10         4.941046  2.396382e+11
# max              93.850207   2.724354e+12        55.072877  1.831677e+13
#
#        GDP_growth  GDP_per_capita  Government_expenditure  ...  \
# count  640.000000      640.000000              640.000000  ...
# mean     5.031779     2998.952195               13.060305  ...
# std      5.099434     2944.567670                7.357437  ...
# min    -32.908829      195.716621                2.360137  ...
# 25%      3.306357      876.653091                9.517356  ...
# 50%      5.389308     1929.842081               11.922478  ...
# 75%      7.297413     4083.116382               15.181854  ...
# max     37.507870    13478.459628               84.193508  ...
#
#        Imports_percent_GDP  Industry_value_added   Inflation  Life_expectancy  \
# count           640.000000            640.000000  640.000000       640.000000
# mean             42.016446             29.652740   10.179179        69.487403
# std              19.959060             10.061512   24.295631         4.925249
# min               8.493486              2.758632   -8.525170        53.781000
# 25%              24.981904             22.567974    3.025008        66.419000
# 50%              40.468576             28.335977    5.934045        69.858000
# 75%              57.202346             36.547975    9.358842        72.975500
# max             121.377661             66.160329  411.759642        81.041000
#
#        Manufacturing_value_added    Population  Population_growth  \
# count                 640.000000  6.400000e+02         640.000000
# mean                   14.692167  1.534916e+08           1.377986
# std                     7.213944  3.394939e+08           1.296753
# min                     0.723331  4.136170e+05          -3.218371
# 25%                     9.067853  6.037424e+06           0.868242
# 50%                    14.347233  2.246143e+07           1.350935
# 75%                    19.284622  1.056687e+08           1.827360
# max                    31.994521  1.438070e+09           9.992305
#
#        Services_value_added  Trade_percent_GDP  Unemployment
# count            640.000000         640.000000    640.000000
# mean              49.005909          76.148398      6.455680
# std                9.582254          35.313455      4.624066
# min               21.755963          16.987727      0.119000
# 25%               42.202981          46.353324      3.083000
# 50%               49.900928          71.928455      5.184000
# 75%               54.131528         100.388354      9.790250
# max               94.148335         186.675833     21.439000
#
# [8 rows x 21 columns]

# %%
print(df.columns)
df['Country'].value_counts()
df['Year'].value_counts()
# Out:
# Index(['Country', 'Country_Code', 'Year', 'Agriculture_value_added',
#        'Current_account_balance', 'Exports_percent_GDP', 'External_debt',
#        'FDI_percent_GDP', 'GDP_USD', 'GDP_growth', 'GDP_per_capita',
#        'Government_expenditure', 'Gross_capital_formation',
#        'Imports_percent_GDP', 'Industry_value_added', 'Inflation',
#        'Life_expectancy', 'Manufacturing_value_added', 'Population',
#        'Population_growth', 'Services_value_added', 'Trade_percent_GDP',
#        'Unemployment'],
#       dtype='object')
# Year
# 2015    27
# 2016    27
# 2020    26
# 2017    25
# 2014    25
# 2018    25
# 2019    25
# 2021    25
# 2012    24
# 2013    24
# 2022    23
# 2023    22
# 2011    22
# 2009    21
# 2006    20
# 2007    20
# 2010    20
# 2008    20
# 2005    19
# 2004    18
# 2000    18
# 2003    17
# 2002    17
# 2001    17
# 1997    16
# 1998    16
# 1999    16
# 1996    15
# 1995    13
# 1994    10
# 1993    10
# 1991     9
# 1992     8
# Name: count, dtype: int64

# %%
numeric_df = df.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                                Year  Agriculture_value_added  \
# Year                       1.000000                -0.397240
# Agriculture_value_added   -0.397240                 1.000000
# Current_account_balance   -0.011597                 0.030473
# Exports_percent_GDP        0.109373                -0.304780
# External_debt              0.214813                -0.198410
# FDI_percent_GDP            0.003764                -0.143810
# GDP_USD                    0.172246                -0.149352
# GDP_growth                -0.084356                 0.049057
# GDP_per_capita             0.509855                -0.647861
# Government_expenditure     0.144721                -0.190700
# Gross_capital_formation    0.191836                -0.184141
# Imports_percent_GDP        0.128500                -0.114872
# Industry_value_added       0.060872                -0.385615
# Inflation                 -0.208905                 0.063672
# Life_expectancy            0.598560                -0.707852
# Manufacturing_value_added -0.132608                -0.116480
# Population                 0.034584                -0.010251
# Population_growth         -0.166851                 0.098261
# Services_value_added       0.243935                -0.519490
# Trade_percent_GDP          0.129158                -0.222453
# Unemployment              -0.046296                -0.278532
#
#                            Current_account_balance  Exports_percent_GDP  \
# Year                                     -0.011597             0.109373
# Agriculture_value_added                   0.030473            -0.304780
# Current_account_balance                   1.000000            -0.057947
# Exports_percent_GDP                      -0.057947             1.000000
# External_debt                             0.057341            -0.147557
# FDI_percent_GDP                          -0.249721             0.351095
# GDP_USD                                   0.059678            -0.140910
# GDP_growth                                0.027213             0.130494
# GDP_per_capita                           -0.047170             0.213764
# Government_expenditure                    0.348081             0.016442
# Gross_capital_formation                  -0.101083             0.048856
# Imports_percent_GDP                      -0.111070             0.707587
# Industry_value_added                      0.188956             0.335212
# Inflation                                -0.011050            -0.050463
# Life_expectancy                          -0.110726             0.322737
# Manufacturing_value_added                 0.024278             0.120260
# Population                                0.080961            -0.278818
# Population_growth                        -0.018213             0.009538
# Services_value_added                     -0.084283            -0.106480
# Trade_percent_GDP                        -0.092727             0.916784
# Unemployment                             -0.094225            -0.135225
#
#                            External_debt  FDI_percent_GDP   GDP_USD  \
# Year                            0.214813         0.003764  0.172246
# Agriculture_value_added        -0.198410        -0.143810 -0.149352
# Current_account_balance         0.057341        -0.249721  0.059678
# Exports_percent_GDP            -0.147557         0.351095 -0.140910
# External_debt                   1.000000        -0.100478  0.972893
# FDI_percent_GDP                -0.100478         1.000000 -0.076489
# GDP_USD                         0.972893        -0.076489  1.000000
# GDP_growth                      0.037011         0.191233  0.061765
# GDP_per_capita                  0.438105         0.060939  0.351339
# Government_expenditure          0.017638        -0.014167  0.044790
# Gross_capital_formation         0.259617         0.255270  0.273342
# Imports_percent_GDP            -0.283276         0.411760 -0.242617
# Industry_value_added            0.191681         0.086401  0.180145
# Inflation                      -0.047434        -0.003301 -0.057094
# Life_expectancy                 0.298413         0.074591  0.259032
# Manufacturing_value_added       0.371513        -0.138451  0.329752
# Population                      0.682603        -0.144438  0.685621
# Population_growth              -0.140892        -0.018194 -0.133755
# Services_value_added            0.066223        -0.060369  0.042467
# Trade_percent_GDP              -0.236372         0.414192 -0.209957
# Unemployment                   -0.064194         0.050638 -0.067743
#
#                            GDP_growth  GDP_per_capita  Government_expenditure  \
# Year                        -0.084356        0.509855                0.144721
# Agriculture_value_added      0.049057       -0.647861               -0.190700
# Current_account_balance      0.027213       -0.047170                0.348081
# Exports_percent_GDP          0.130494        0.213764                0.016442
# External_debt                0.037011        0.438105                0.017638
# FDI_percent_GDP              0.191233        0.060939               -0.014167
# GDP_USD                      0.061765        0.351339                0.044790
# GDP_growth                   1.000000       -0.036991               -0.097909
# GDP_per_capita              -0.036991        1.000000                0.094097
# Government_expenditure      -0.097909        0.094097                1.000000
# Gross_capital_formation      0.230501        0.143500                0.214146
# Imports_percent_GDP          0.070084       -0.023589                0.366346
# Industry_value_added         0.131438        0.150000               -0.073581
# Inflation                   -0.232267       -0.054400               -0.035492
# Life_expectancy             -0.071954        0.698192                0.139674
# Manufacturing_value_added    0.046969        0.002265               -0.285831
# Population                   0.104959        0.046578               -0.067967
# Population_growth            0.061779       -0.112134                0.097370
# Services_value_added        -0.226160        0.389393                0.292791
# Trade_percent_GDP            0.107058        0.097153                0.215556
# Unemployment                -0.089444        0.123767                0.107621
#
#                            ...  Imports_percent_GDP  Industry_value_added  \
# Year                       ...             0.128500              0.060872
# Agriculture_value_added    ...            -0.114872             -0.385615
# Current_account_balance    ...            -0.111070              0.188956
# Exports_percent_GDP        ...             0.707587              0.335212
# External_debt              ...            -0.283276              0.191681
# FDI_percent_GDP            ...             0.411760              0.086401
# GDP_USD                    ...            -0.242617              0.180145
# GDP_growth                 ...             0.070084              0.131438
# GDP_per_capita             ...            -0.023589              0.150000
# Government_expenditure     ...             0.366346             -0.073581
# Gross_capital_formation    ...             0.224794              0.205403
# Imports_percent_GDP        ...             1.000000             -0.132643
# Industry_value_added       ...            -0.132643              1.000000
# Inflation                  ...            -0.048893             -0.023188
# Life_expectancy            ...             0.244880              0.130167
# Manufacturing_value_added  ...            -0.120298              0.321429
# Population                 ...            -0.411142              0.147176
# Population_growth          ...             0.115330             -0.110913
# Services_value_added       ...             0.136861             -0.499337
# Trade_percent_GDP          ...             0.930919              0.098288
# Unemployment               ...             0.014408             -0.177954
#
#                            Inflation  Life_expectancy  \
# Year                       -0.208905         0.598560
# Agriculture_value_added     0.063672        -0.707852
# Current_account_balance    -0.011050        -0.110726
# Exports_percent_GDP        -0.050463         0.322737
# External_debt              -0.047434         0.298413
# FDI_percent_GDP            -0.003301         0.074591
# GDP_USD                    -0.057094         0.259032
# GDP_growth                 -0.232267        -0.071954
# GDP_per_capita             -0.054400         0.698192
# Government_expenditure     -0.035492         0.139674
# Gross_capital_formation    -0.096976         0.256621
# Imports_percent_GDP        -0.048893         0.244880
# Industry_value_added       -0.023188         0.130167
# Inflation                   1.000000        -0.109450
# Life_expectancy            -0.109450         1.000000
# Manufacturing_value_added   0.015605         0.179564
# Population                 -0.066870         0.020480
# Population_growth          -0.081108        -0.188295
# Services_value_added       -0.037148         0.473539
# Trade_percent_GDP          -0.053717         0.305215
# Unemployment                0.051893         0.231598
#
#                            Manufacturing_value_added  Population  \
# Year                                       -0.132608    0.034584
# Agriculture_value_added                    -0.116480   -0.010251
# Current_account_balance                     0.024278    0.080961
# Exports_percent_GDP                         0.120260   -0.278818
# External_debt                               0.371513    0.682603
# FDI_percent_GDP                            -0.138451   -0.144438
# GDP_USD                                     0.329752    0.685621
# GDP_growth                                  0.046969    0.104959
# GDP_per_capita                              0.002265    0.046578
# Government_expenditure                     -0.285831   -0.067967
# Gross_capital_formation                     0.027695    0.238605
# Imports_percent_GDP                        -0.120298   -0.411142
# Industry_value_added                        0.321429    0.147176
# Inflation                                   0.015605   -0.066870
# Life_expectancy                             0.179564    0.020480
# Manufacturing_value_added                   1.000000    0.349330
# Population                                  0.349330    1.000000
# Population_growth                          -0.081039   -0.068078
# Services_value_added                       -0.057621   -0.084193
# Trade_percent_GDP                          -0.005834   -0.376486
# Unemployment                               -0.294538   -0.075894
#
#                            Population_growth  Services_value_added  \
# Year                               -0.166851              0.243935
# Agriculture_value_added             0.098261             -0.519490
# Current_account_balance            -0.018213             -0.084283
# Exports_percent_GDP                 0.009538             -0.106480
# External_debt                      -0.140892              0.066223
# FDI_percent_GDP                    -0.018194             -0.060369
# GDP_USD                            -0.133755              0.042467
# GDP_growth                          0.061779             -0.226160
# GDP_per_capita                     -0.112134              0.389393
# Government_expenditure              0.097370              0.292791
# Gross_capital_formation            -0.045634             -0.062864
# Imports_percent_GDP                 0.115330              0.136861
# Industry_value_added               -0.110913             -0.499337
# Inflation                          -0.081108             -0.037148
# Life_expectancy                    -0.188295              0.473539
# Manufacturing_value_added          -0.081039             -0.057621
# Population                         -0.068078             -0.084193
# Population_growth                   1.000000             -0.018113
# Services_value_added               -0.018113              1.000000
# Trade_percent_GDP                   0.070114              0.022318
# Unemployment                       -0.092816              0.307298
#
#                            Trade_percent_GDP  Unemployment
# Year                                0.129158     -0.046296
# Agriculture_value_added            -0.222453     -0.278532
# Current_account_balance            -0.092727     -0.094225
# Exports_percent_GDP                 0.916784     -0.135225
# External_debt                      -0.236372     -0.064194
# FDI_percent_GDP                     0.414192      0.050638
# GDP_USD                            -0.209957     -0.067743
# GDP_growth                          0.107058     -0.089444
# GDP_per_capita                      0.097153      0.123767
# Government_expenditure              0.215556      0.107621
# Gross_capital_formation             0.152305     -0.081075
# Imports_percent_GDP                 0.930919      0.014408
# Industry_value_added                0.098288     -0.177954
# Inflation                          -0.053717      0.051893
# Life_expectancy                     0.305215      0.231598
# Manufacturing_value_added          -0.005834     -0.294538
# Population                         -0.376486     -0.075894
# Population_growth                   0.070114     -0.092816
# Services_value_added                0.022318      0.307298
# Trade_percent_GDP                   1.000000     -0.061749
# Unemployment                       -0.061749      1.000000
#
# [21 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
